# %%
# !yolo task=detect mode=train model=yolov8x data=r"C:\Users\salwa\OneDrive\Desktop\tennis project\training\tennis-ball-detection-6\data.yaml" epochs=100 imgsz=640
# Out:
# ^C
# ...
# New https://pypi.org/project/ultralytics/8.2.86 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.85 🚀 Python-3.11.7 torch-2.3.1+cpu CPU (11th Gen Intel Core(TM) i5-1155G7 2.50GHz)
# ...
